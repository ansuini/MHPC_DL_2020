# %% [markdown]
# # MNIST
#
# Training of a small MLP on MNIST with a custom loss function

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

# %%
# Training settings
batch_size=64
epochs=10
lr=0.01
momentum=0.0
seed=1101

din=784
dout=10
dh=50

nbatches=30 # n.batches to evaluate statistics

# %%
class Net(nn.Module):
    def __init__(self,din=784, dh=30, dout=10):
        super(Net, self).__init__()
        
        self.lin1 = nn.Linear(din, dh)
        self.lin2 = nn.Linear(dh, dout)
    
    def forward(self, x):    
        x = torch.sigmoid(self.lin1(x)) 
        return self.lin2(x)

# %% [markdown]
# ### New loss function
#
# Try to use a Minkowski loss with parameter q
#
# $$
# d_q(x,y) = \left( \sum_i (x_i - y_i )^q \right)^{1/q}
# $$
#
# the only goal here is to learn how to define a new loss.
# The class MinkowskiLoss receives a minibatch of data and
# returns the average Minkowski distance over a minibatch.

# %%
class MinkowskiLoss(torch.nn.Module):
    def __init__(self,q):
        super(MinkowskiLoss,self).__init__()
        self.q = q
        
    def forward(self,x,y):
        
        return loss

# %%
q = 6
criterion = MinkowskiLoss(q)

# %%
def train(model, device, train_loader, optimizer, epoch):
    model.train()
    

    for batch_idx, (data, target) in enumerate(train_loader):
        
       
        data, target = data.to(device), target.to(device)
                
        data = data.view(-1,784) # *
        target = target.view(-1,1) # *
        onehot = torch.FloatTensor(data.shape[0], 10).zero_().to(device) # *
        onehot.scatter_(1, target, 1) # *
        target = onehot # *
    
        optimizer.zero_grad()
        output = model(data)    
        loss = criterion(output, target)
    
        
        loss.backward()
        optimizer.step()

# %%
def stats(model, device, loader, nsamples=batch_size*nbatches):
    
    model.eval() 
    
    loss = 0
    correct = 0
    count = 0
    
    origin = 'train' if loader.dataset.train else 'test'
    
    with torch.no_grad():
        
        for data, target in loader:
            
            count += data.shape[0]
                
            if count > nsamples:
                break
                
            data, target = data.to(device), target.to(device)     
            
            
            data = data.view(-1,784) # *
            target = target.view(-1,1) # *
            onehot = torch.FloatTensor(data.shape[0], 10).zero_().to(device) # *
            onehot.scatter_(1, target, 1) # *
            
    
            output = model(data)
            
            loss += criterion(output, onehot).item()
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    loss /= count  
    acc = 100. * correct / count
    

    print('\n{} set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(origin,
        loss, correct, count,
        acc ) )
    
    
    return loss,acc

# %%
use_cuda = torch.cuda.is_available()
torch.manual_seed(seed)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
train_loader = torch.utils.data.DataLoader(
        datasets.MNIST('../data', train=True, download=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('../data', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=batch_size, shuffle=True, **kwargs)

# %%
model = Net(din,dh,dout).to(device)
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)

# %%
train_stats = []
test_stats = []

for epoch in range(1, epochs + 1):
    
    train(model, device, train_loader, optimizer, epoch)
    
    train_stats.append(stats(model, device, train_loader))
    test_stats.append(stats(model, device, test_loader))
    
train_stats = np.array(train_stats)
test_stats = np.array(test_stats)
# Out:
# tensor(1.0635, grad_fn=<DivBackward0>)
# tensor(0.9861, grad_fn=<DivBackward0>)
# tensor(0.9902, grad_fn=<DivBackward0>)
# tensor(0.9447, grad_fn=<DivBackward0>)
# tensor(0.9765, grad_fn=<DivBackward0>)
# tensor(0.9390, grad_fn=<DivBackward0>)
# tensor(0.9399, grad_fn=<DivBackward0>)
# tensor(0.8941, grad_fn=<DivBackward0>)
# tensor(0.8631, grad_fn=<DivBackward0>)
# tensor(0.9092, grad_fn=<DivBackward0>)
# tensor(0.8322, grad_fn=<DivBackward0>)
# tensor(0.7905, grad_fn=<DivBackward0>)
# tensor(0.8054, grad_fn=<DivBackward0>)
# tensor(0.8234, grad_fn=<DivBackward0>)
# tensor(0.7773, grad_fn=<DivBackward0>)
# tensor(0.7876, grad_fn=<DivBackward0>)
# tensor(0.7845, grad_fn=<DivBackward0>)
# tensor(0.7778, grad_fn=<DivBackward0>)
# tensor(0.7234, grad_fn=<DivBackward0>)
# tensor(0.7241, grad_fn=<DivBackward0>)
# tensor(0.7481, grad_fn=<DivBackward0>)
# tensor(0.7226, grad_fn=<DivBackward0>)
# tensor(0.7066, grad_fn=<DivBackward0>)
# tensor(0.7083, grad_fn=<DivBackward0>)
# tensor(0.6901, grad_fn=<DivBackward0>)
# tensor(0.6945, grad_fn=<DivBackward0>)
# tensor(0.6720, grad_fn=<DivBackward0>)
# tensor(0.6702, grad_fn=<DivBackward0>)
# tensor(0.6823, grad_fn=<DivBackward0>)
# tensor(0.6655, grad_fn=<DivBackward0>)
# tensor(0.6595, grad_fn=<DivBackward0>)
# tensor(0.6465, grad_fn=<DivBackward0>)
# tensor(0.6505, grad_fn=<DivBackward0>)
# tensor(0.6516, grad_fn=<DivBackward0>)
# tensor(0.6596, grad_fn=<DivBackward0>)
# tensor(0.6574, grad_fn=<DivBackward0>)
# tensor(0.6683, grad_fn=<DivBackward0>)
# tensor(0.6468, grad_fn=<DivBackward0>)
# tensor(0.6383, grad_fn=<DivBackward0>)
# tensor(0.6329, grad_fn=<DivBackward0>)
# tensor(0.6320, grad_fn=<DivBackward0>)
# tensor(0.6314, grad_fn=<DivBackward0>)
# tensor(0.6476, grad_fn=<DivBackward0>)
# tensor(0.6301, grad_fn=<DivBackward0>)
# tensor(0.6351, grad_fn=<DivBackward0>)
# tensor(0.6337, grad_fn=<DivBackward0>)
# tensor(0.6274, grad_fn=<DivBackward0>)
# tensor(0.6279, grad_fn=<DivBackward0>)
# tensor(0.6161, grad_fn=<DivBackward0>)
# tensor(0.6332, grad_fn=<DivBackward0>)
# tensor(0.6314, grad_fn=<DivBackward0>)
# tensor(0.6165, grad_fn=<DivBackward0>)
# tensor(0.6293, grad_fn=<DivBackward0>)
# tensor(0.6260, grad_fn=<DivBackward0>)
# tensor(0.6212, grad_fn=<DivBackward0>)
# tensor(0.6202, grad_fn=<DivBackward0>)
# tensor(0.6190, grad_fn=<DivBackward0>)
# tensor(0.6240, grad_fn=<DivBackward0>)
# tensor(0.6155, grad_fn=<DivBackward0>)
# tensor(0.6252, grad_fn=<DivBackward0>)
# tensor(0.6112, grad_fn=<DivBackward0>)
# tensor(0.6342, grad_fn=<DivBackward0>)
# tensor(0.6211, grad_fn=<DivBackward0>)
# tensor(0.6262, grad_fn=<DivBackward0>)
# tensor(0.6038, grad_fn=<DivBackward0>)
# tensor(0.6178, grad_fn=<DivBackward0>)
# tensor(0.6110, grad_fn=<DivBackward0>)
# tensor(0.6096, grad_fn=<DivBackward0>)
# tensor(0.6186, grad_fn=<DivBackward0>)
# tensor(0.6221, grad_fn=<DivBackward0>)
# tensor(0.6107, grad_fn=<DivBackward0>)
# tensor(0.5989, grad_fn=<DivBackward0>)
# tensor(0.6149, grad_fn=<DivBackward0>)
# tensor(0.6141, grad_fn=<DivBackward0>)
# tensor(0.6143, grad_fn=<DivBackward0>)
# tensor(0.6182, grad_fn=<DivBackward0>)
# tensor(0.6181, grad_fn=<DivBackward0>)
# tensor(0.5946, grad_fn=<DivBackward0>)
# tensor(0.6066, grad_fn=<DivBackward0>)
# tensor(0.6141, grad_fn=<DivBackward0>)
# tensor(0.6172, grad_fn=<DivBackward0>)
# tensor(0.5916, grad_fn=<DivBackward0>)
# tensor(0.6009, grad_fn=<DivBackward0>)
# tensor(0.5944, grad_fn=<DivBackward0>)
# tensor(0.6089, grad_fn=<DivBackward0>)
# tensor(0.5999, grad_fn=<DivBackward0>)
# tensor(0.5932, grad_fn=<DivBackward0>)
# tensor(0.5912, grad_fn=<DivBackward0>)
# tensor(0.5940, grad_fn=<DivBackward0>)
# tensor(0.6127, grad_fn=<DivBackward0>)
# tensor(0.5971, grad_fn=<DivBackward0>)
# tensor(0.5919, grad_fn=<DivBackward0>)
# tensor(0.5902, grad_fn=<DivBackward0>)
# tensor(0.5937, grad_fn=<DivBackward0>)
# tensor(0.6024, grad_fn=<DivBackward0>)
# tensor(0.6077, grad_fn=<DivBackward0>)
# tensor(0.5884, grad_fn=<DivBackward0>)
# tensor(0.6068, grad_fn=<DivBackward0>)
# tensor(0.5987, grad_fn=<DivBackward0>)
# tensor(0.5690, grad_fn=<DivBackward0>)
# tensor(0.5844, grad_fn=<DivBackward0>)
# tensor(0.5873, grad_fn=<DivBackward0>)
# tensor(0.6002, grad_fn=<DivBackward0>)
# tensor(0.6037, grad_fn=<DivBackward0>)
# tensor(0.5912, grad_fn=<DivBackward0>)
# tensor(0.5938, grad_fn=<DivBackward0>)
# tensor(0.6104, grad_fn=<DivBackward0>)
# tensor(0.5961, grad_fn=<DivBackward0>)
# tensor(0.5880, grad_fn=<DivBackward0>)
# tensor(0.6039, grad_fn=<DivBackward0>)
# tensor(0.5946, grad_fn=<DivBackward0>)
# tensor(0.5886, grad_fn=<DivBackward0>)
# tensor(0.5842, grad_fn=<DivBackward0>)
# tensor(0.5750, grad_fn=<DivBackward0>)
# tensor(0.5793, grad_fn=<DivBackward0>)
# tensor(0.5801, grad_fn=<DivBackward0>)
# tensor(0.5999, grad_fn=<DivBackward0>)
# tensor(0.5973, grad_fn=<DivBackward0>)
# tensor(0.5859, grad_fn=<DivBackward0>)
# tensor(0.6092, grad_fn=<DivBackward0>)
# tensor(0.5739, grad_fn=<DivBackward0>)
# tensor(0.5889, grad_fn=<DivBackward0>)
# tensor(0.5800, grad_fn=<DivBackward0>)
# tensor(0.5790, grad_fn=<DivBackward0>)
# tensor(0.5798, grad_fn=<DivBackward0>)
# tensor(0.5795, grad_fn=<DivBackward0>)
# tensor(0.5909, grad_fn=<DivBackward0>)
# tensor(0.5857, grad_fn=<DivBackward0>)
# tensor(0.5747, grad_fn=<DivBackward0>)
# tensor(0.5817, grad_fn=<DivBackward0>)
# tensor(0.5961, grad_fn=<DivBackward0>)
# tensor(0.5653, grad_fn=<DivBackward0>)
# tensor(0.5634, grad_fn=<DivBackward0>)
# tensor(0.5869, grad_fn=<DivBackward0>)
# tensor(0.5695, grad_fn=<DivBackward0>)
# tensor(0.5829, grad_fn=<DivBackward0>)
# tensor(0.5878, grad_fn=<DivBackward0>)
# tensor(0.5748, grad_fn=<DivBackward0>)
# tensor(0.5686, grad_fn=<DivBackward0>)
# tensor(0.5648, grad_fn=<DivBackward0>)
# tensor(0.5770, grad_fn=<DivBackward0>)
# tensor(0.5728, grad_fn=<DivBackward0>)
# tensor(0.5807, grad_fn=<DivBackward0>)
# tensor(0.5836, grad_fn=<DivBackward0>)
# tensor(0.5719, grad_fn=<DivBackward0>)
# tensor(0.5679, grad_fn=<DivBackward0>)
# tensor(0.5741, grad_fn=<DivBackward0>)
# tensor(0.5819, grad_fn=<DivBackward0>)
# tensor(0.5660, grad_fn=<DivBackward0>)
# tensor(0.5643, grad_fn=<DivBackward0>)
# tensor(0.5719, grad_fn=<DivBackward0>)
# tensor(0.5726, grad_fn=<DivBackward0>)
# tensor(0.5654, grad_fn=<DivBackward0>)
# tensor(0.5692, grad_fn=<DivBackward0>)
# tensor(0.5733, grad_fn=<DivBackward0>)
# tensor(0.5519, grad_fn=<DivBackward0>)
# tensor(0.5775, grad_fn=<DivBackward0>)
# tensor(0.5595, grad_fn=<DivBackward0>)
# tensor(0.5691, grad_fn=<DivBackward0>)
# tensor(0.5487, grad_fn=<DivBackward0>)
# tensor(0.5836, grad_fn=<DivBackward0>)
# tensor(0.5564, grad_fn=<DivBackward0>)
# tensor(0.5689, grad_fn=<DivBackward0>)
# tensor(0.5472, grad_fn=<DivBackward0>)
# tensor(0.5575, grad_fn=<DivBackward0>)
# tensor(0.5588, grad_fn=<DivBackward0>)
# tensor(0.5607, grad_fn=<DivBackward0>)
# tensor(0.5560, grad_fn=<DivBackward0>)
# tensor(0.5795, grad_fn=<DivBackward0>)
# tensor(0.5640, grad_fn=<DivBackward0>)
# tensor(0.5779, grad_fn=<DivBackward0>)
# tensor(0.5712, grad_fn=<DivBackward0>)
# tensor(0.5633, grad_fn=<DivBackward0>)
# tensor(0.5533, grad_fn=<DivBackward0>)
# tensor(0.5674, grad_fn=<DivBackward0>)
# tensor(0.5575, grad_fn=<DivBackward0>)
# tensor(0.5506, grad_fn=<DivBackward0>)
# tensor(0.5743, grad_fn=<DivBackward0>)
# tensor(0.5434, grad_fn=<DivBackward0>)
# tensor(0.5768, grad_fn=<DivBackward0>)
# tensor(0.5595, grad_fn=<DivBackward0>)
# tensor(0.5558, grad_fn=<DivBackward0>)
# tensor(0.5581, grad_fn=<DivBackward0>)
# tensor(0.5520, grad_fn=<DivBackward0>)
# tensor(0.5586, grad_fn=<DivBackward0>)
# tensor(0.5536, grad_fn=<DivBackward0>)
# tensor(0.5383, grad_fn=<DivBackward0>)
# tensor(0.5440, grad_fn=<DivBackward0>)
# tensor(0.5784, grad_fn=<DivBackward0>)
# tensor(0.5574, grad_fn=<DivBackward0>)
# tensor(0.5672, grad_fn=<DivBackward0>)
# tensor(0.5414, grad_fn=<DivBackward0>)
# tensor(0.5373, grad_fn=<DivBackward0>)
# tensor(0.5522, grad_fn=<DivBackward0>)
# tensor(0.5496, grad_fn=<DivBackward0>)
# tensor(0.5476, grad_fn=<DivBackward0>)
# tensor(0.5574, grad_fn=<DivBackward0>)
# tensor(0.5573, grad_fn=<DivBackward0>)
# tensor(0.5347, grad_fn=<DivBackward0>)
# tensor(0.5334, grad_fn=<DivBackward0>)
# tensor(0.5425, grad_fn=<DivBackward0>)
# tensor(0.5451, grad_fn=<DivBackward0>)
# tensor(0.5543, grad_fn=<DivBackward0>)
# tensor(0.5357, grad_fn=<DivBackward0>)
# tensor(0.5548, grad_fn=<DivBackward0>)
# tensor(0.5541, grad_fn=<DivBackward0>)
# tensor(0.5331, grad_fn=<DivBackward0>)
# tensor(0.5363, grad_fn=<DivBackward0>)
# tensor(0.5461, grad_fn=<DivBackward0>)
# tensor(0.5341, grad_fn=<DivBackward0>)
# tensor(0.5595, grad_fn=<DivBackward0>)
# tensor(0.5472, grad_fn=<DivBackward0>)
# tensor(0.5486, grad_fn=<DivBackward0>)
# tensor(0.5357, grad_fn=<DivBackward0>)
# tensor(0.5387, grad_fn=<DivBackward0>)
# tensor(0.5292, grad_fn=<DivBackward0>)
# tensor(0.5651, grad_fn=<DivBackward0>)
# tensor(0.5629, grad_fn=<DivBackward0>)
# tensor(0.5271, grad_fn=<DivBackward0>)
# tensor(0.5292, grad_fn=<DivBackward0>)
# tensor(0.5547, grad_fn=<DivBackward0>)
# tensor(0.5447, grad_fn=<DivBackward0>)
# tensor(0.5512, grad_fn=<DivBackward0>)
# tensor(0.5305, grad_fn=<DivBackward0>)
# tensor(0.5480, grad_fn=<DivBackward0>)
# tensor(0.5382, grad_fn=<DivBackward0>)
# tensor(0.5467, grad_fn=<DivBackward0>)
# tensor(0.5481, grad_fn=<DivBackward0>)
# tensor(0.5435, grad_fn=<DivBackward0>)
# tensor(0.5439, grad_fn=<DivBackward0>)
# tensor(0.5308, grad_fn=<DivBackward0>)
# tensor(0.5355, grad_fn=<DivBackward0>)
# tensor(0.5541, grad_fn=<DivBackward0>)
# tensor(0.5687, grad_fn=<DivBackward0>)
# tensor(0.5491, grad_fn=<DivBackward0>)
# tensor(0.5258, grad_fn=<DivBackward0>)
# tensor(0.5454, grad_fn=<DivBackward0>)
# tensor(0.5251, grad_fn=<DivBackward0>)
# tensor(0.5437, grad_fn=<DivBackward0>)
# tensor(0.5414, grad_fn=<DivBackward0>)
# tensor(0.5332, grad_fn=<DivBackward0>)
# tensor(0.5488, grad_fn=<DivBackward0>)
# tensor(0.5245, grad_fn=<DivBackward0>)
# tensor(0.5422, grad_fn=<DivBackward0>)
# tensor(0.5434, grad_fn=<DivBackward0>)
# tensor(0.5114, grad_fn=<DivBackward0>)
# tensor(0.5316, grad_fn=<DivBackward0>)
# tensor(0.5247, grad_fn=<DivBackward0>)
# tensor(0.5151, grad_fn=<DivBackward0>)
# tensor(0.5390, grad_fn=<DivBackward0>)
# tensor(0.5296, grad_fn=<DivBackward0>)
# tensor(0.5361, grad_fn=<DivBackward0>)
# tensor(0.5197, grad_fn=<DivBackward0>)
# tensor(0.5412, grad_fn=<DivBackward0>)
# tensor(0.5298, grad_fn=<DivBackward0>)
# tensor(0.5242, grad_fn=<DivBackward0>)
# tensor(0.5316, grad_fn=<DivBackward0>)
# tensor(0.5412, grad_fn=<DivBackward0>)
# tensor(0.5078, grad_fn=<DivBackward0>)
# tensor(0.5482, grad_fn=<DivBackward0>)
# tensor(0.5445, grad_fn=<DivBackward0>)
# tensor(0.5294, grad_fn=<DivBackward0>)
# tensor(0.5266, grad_fn=<DivBackward0>)
# tensor(0.5491, grad_fn=<DivBackward0>)
# tensor(0.5227, grad_fn=<DivBackward0>)
# tensor(0.5189, grad_fn=<DivBackward0>)
# tensor(0.5171, grad_fn=<DivBackward0>)
# tensor(0.5301, grad_fn=<DivBackward0>)
# tensor(0.5427, grad_fn=<DivBackward0>)
# tensor(0.5424, grad_fn=<DivBackward0>)
# tensor(0.5219, grad_fn=<DivBackward0>)
# tensor(0.5366, grad_fn=<DivBackward0>)
# tensor(0.5223, grad_fn=<DivBackward0>)
# tensor(0.5264, grad_fn=<DivBackward0>)
# tensor(0.5428, grad_fn=<DivBackward0>)
# tensor(0.5336, grad_fn=<DivBackward0>)
# tensor(0.5215, grad_fn=<DivBackward0>)
# tensor(0.5400, grad_fn=<DivBackward0>)
# tensor(0.5318, grad_fn=<DivBackward0>)
# tensor(0.5278, grad_fn=<DivBackward0>)
# tensor(0.5054, grad_fn=<DivBackward0>)
# tensor(0.5252, grad_fn=<DivBackward0>)
# tensor(0.5233, grad_fn=<DivBackward0>)
# tensor(0.5239, grad_fn=<DivBackward0>)
# tensor(0.5100, grad_fn=<DivBackward0>)
# tensor(0.5354, grad_fn=<DivBackward0>)
# tensor(0.5231, grad_fn=<DivBackward0>)
# tensor(0.5417, grad_fn=<DivBackward0>)
# tensor(0.5191, grad_fn=<DivBackward0>)
# tensor(0.5195, grad_fn=<DivBackward0>)
# tensor(0.4857, grad_fn=<DivBackward0>)
# tensor(0.5183, grad_fn=<DivBackward0>)
# tensor(0.5037, grad_fn=<DivBackward0>)
# tensor(0.5064, grad_fn=<DivBackward0>)
# tensor(0.5018, grad_fn=<DivBackward0>)
# tensor(0.5295, grad_fn=<DivBackward0>)
# tensor(0.5261, grad_fn=<DivBackward0>)
# tensor(0.5244, grad_fn=<DivBackward0>)
# tensor(0.4927, grad_fn=<DivBackward0>)
# tensor(0.5109, grad_fn=<DivBackward0>)
# tensor(0.5180, grad_fn=<DivBackward0>)
# tensor(0.5265, grad_fn=<DivBackward0>)
# tensor(0.5321, grad_fn=<DivBackward0>)
# tensor(0.5204, grad_fn=<DivBackward0>)
# tensor(0.5364, grad_fn=<DivBackward0>)
# tensor(0.5431, grad_fn=<DivBackward0>)
# tensor(0.4972, grad_fn=<DivBackward0>)
# tensor(0.5301, grad_fn=<DivBackward0>)
# tensor(0.5096, grad_fn=<DivBackward0>)
# tensor(0.5333, grad_fn=<DivBackward0>)
# tensor(0.5175, grad_fn=<DivBackward0>)
# tensor(0.5001, grad_fn=<DivBackward0>)
# tensor(0.5154, grad_fn=<DivBackward0>)
# tensor(0.5182, grad_fn=<DivBackward0>)
# tensor(0.5301, grad_fn=<DivBackward0>)
# tensor(0.5292, grad_fn=<DivBackward0>)
# tensor(0.5206, grad_fn=<DivBackward0>)
# tensor(0.4909, grad_fn=<DivBackward0>)
# tensor(0.5116, grad_fn=<DivBackward0>)
# tensor(0.5107, grad_fn=<DivBackward0>)
# tensor(0.4994, grad_fn=<DivBackward0>)
# tensor(0.5293, grad_fn=<DivBackward0>)
# tensor(0.4992, grad_fn=<DivBackward0>)
# tensor(0.5098, grad_fn=<DivBackward0>)
# tensor(0.5028, grad_fn=<DivBackward0>)
# tensor(0.5372, grad_fn=<DivBackward0>)
# tensor(0.5102, grad_fn=<DivBackward0>)
# tensor(0.4937, grad_fn=<DivBackward0>)
# tensor(0.4925, grad_fn=<DivBackward0>)
# tensor(0.5225, grad_fn=<DivBackward0>)
# tensor(0.5132, grad_fn=<DivBackward0>)
# tensor(0.4796, grad_fn=<DivBackward0>)
# tensor(0.5166, grad_fn=<DivBackward0>)
# tensor(0.5127, grad_fn=<DivBackward0>)
# tensor(0.5185, grad_fn=<DivBackward0>)
# tensor(0.4993, grad_fn=<DivBackward0>)
# tensor(0.5138, grad_fn=<DivBackward0>)
# tensor(0.4987, grad_fn=<DivBackward0>)
# tensor(0.5104, grad_fn=<DivBackward0>)
# tensor(0.5106, grad_fn=<DivBackward0>)
# tensor(0.5168, grad_fn=<DivBackward0>)
# tensor(0.4976, grad_fn=<DivBackward0>)
# tensor(0.5214, grad_fn=<DivBackward0>)
# tensor(0.5271, grad_fn=<DivBackward0>)
# tensor(0.5076, grad_fn=<DivBackward0>)
# tensor(0.5228, grad_fn=<DivBackward0>)
# tensor(0.4909, grad_fn=<DivBackward0>)
# tensor(0.4921, grad_fn=<DivBackward0>)
# tensor(0.5294, grad_fn=<DivBackward0>)
# tensor(0.5393, grad_fn=<DivBackward0>)
# tensor(0.4970, grad_fn=<DivBackward0>)
# tensor(0.5125, grad_fn=<DivBackward0>)
# tensor(0.5159, grad_fn=<DivBackward0>)
# tensor(0.5149, grad_fn=<DivBackward0>)
# tensor(0.4877, grad_fn=<DivBackward0>)
# tensor(0.5133, grad_fn=<DivBackward0>)
# tensor(0.5258, grad_fn=<DivBackward0>)
# tensor(0.5411, grad_fn=<DivBackward0>)
# tensor(0.5264, grad_fn=<DivBackward0>)
# tensor(0.5331, grad_fn=<DivBackward0>)
# tensor(0.4887, grad_fn=<DivBackward0>)
# tensor(0.5028, grad_fn=<DivBackward0>)
# tensor(0.5104, grad_fn=<DivBackward0>)
# tensor(0.4934, grad_fn=<DivBackward0>)
# tensor(0.4874, grad_fn=<DivBackward0>)
# tensor(0.4664, grad_fn=<DivBackward0>)
# tensor(0.4684, grad_fn=<DivBackward0>)
# tensor(0.4943, grad_fn=<DivBackward0>)
# tensor(0.5047, grad_fn=<DivBackward0>)
# tensor(0.5139, grad_fn=<DivBackward0>)
# tensor(0.5153, grad_fn=<DivBackward0>)
# tensor(0.4806, grad_fn=<DivBackward0>)
# tensor(0.4873, grad_fn=<DivBackward0>)
# tensor(0.5002, grad_fn=<DivBackward0>)
# tensor(0.4991, grad_fn=<DivBackward0>)
# tensor(0.5023, grad_fn=<DivBackward0>)
# tensor(0.4863, grad_fn=<DivBackward0>)
# tensor(0.4876, grad_fn=<DivBackward0>)
# tensor(0.5178, grad_fn=<DivBackward0>)
# tensor(0.5261, grad_fn=<DivBackward0>)
# tensor(0.5065, grad_fn=<DivBackward0>)
# tensor(0.5039, grad_fn=<DivBackward0>)
# tensor(0.5037, grad_fn=<DivBackward0>)
# tensor(0.5057, grad_fn=<DivBackward0>)
# tensor(0.5017, grad_fn=<DivBackward0>)
# tensor(0.4678, grad_fn=<DivBackward0>)
# tensor(0.4685, grad_fn=<DivBackward0>)
# tensor(0.5208, grad_fn=<DivBackward0>)
# tensor(0.4775, grad_fn=<DivBackward0>)
# tensor(0.4834, grad_fn=<DivBackward0>)
# tensor(0.5104, grad_fn=<DivBackward0>)
# tensor(0.4570, grad_fn=<DivBackward0>)
# tensor(0.4789, grad_fn=<DivBackward0>)
# tensor(0.5433, grad_fn=<DivBackward0>)
# tensor(0.4708, grad_fn=<DivBackward0>)
# tensor(0.5298, grad_fn=<DivBackward0>)
# tensor(0.4886, grad_fn=<DivBackward0>)
# tensor(0.4606, grad_fn=<DivBackward0>)
# tensor(0.4963, grad_fn=<DivBackward0>)
# tensor(0.5019, grad_fn=<DivBackward0>)
# tensor(0.4878, grad_fn=<DivBackward0>)
# tensor(0.4964, grad_fn=<DivBackward0>)
# tensor(0.4997, grad_fn=<DivBackward0>)
# tensor(0.4933, grad_fn=<DivBackward0>)
# tensor(0.5110, grad_fn=<DivBackward0>)
# tensor(0.4632, grad_fn=<DivBackward0>)
# tensor(0.5192, grad_fn=<DivBackward0>)
# tensor(0.4860, grad_fn=<DivBackward0>)
# tensor(0.4646, grad_fn=<DivBackward0>)
# tensor(0.4742, grad_fn=<DivBackward0>)
# tensor(0.4934, grad_fn=<DivBackward0>)
# tensor(0.5318, grad_fn=<DivBackward0>)
# tensor(0.4664, grad_fn=<DivBackward0>)
# tensor(0.4788, grad_fn=<DivBackward0>)
# tensor(0.5082, grad_fn=<DivBackward0>)
# tensor(0.4603, grad_fn=<DivBackward0>)
# tensor(0.4821, grad_fn=<DivBackward0>)
# tensor(0.4824, grad_fn=<DivBackward0>)
# tensor(0.4901, grad_fn=<DivBackward0>)
# tensor(0.4747, grad_fn=<DivBackward0>)
# tensor(0.5004, grad_fn=<DivBackward0>)
# tensor(0.4781, grad_fn=<DivBackward0>)
# tensor(0.5265, grad_fn=<DivBackward0>)
# tensor(0.4569, grad_fn=<DivBackward0>)
# tensor(0.4863, grad_fn=<DivBackward0>)
# tensor(0.4796, grad_fn=<DivBackward0>)
# tensor(0.4699, grad_fn=<DivBackward0>)
# tensor(0.5013, grad_fn=<DivBackward0>)
# tensor(0.5005, grad_fn=<DivBackward0>)
# tensor(0.4811, grad_fn=<DivBackward0>)
# tensor(0.4970, grad_fn=<DivBackward0>)
# tensor(0.5029, grad_fn=<DivBackward0>)
# tensor(0.5003, grad_fn=<DivBackward0>)
# tensor(0.5075, grad_fn=<DivBackward0>)
# tensor(0.4806, grad_fn=<DivBackward0>)
# tensor(0.4615, grad_fn=<DivBackward0>)
# tensor(0.4794, grad_fn=<DivBackward0>)
# tensor(0.4679, grad_fn=<DivBackward0>)
# tensor(0.5171, grad_fn=<DivBackward0>)
# tensor(0.4722, grad_fn=<DivBackward0>)
# tensor(0.4863, grad_fn=<DivBackward0>)
# tensor(0.4609, grad_fn=<DivBackward0>)
# tensor(0.4797, grad_fn=<DivBackward0>)
# tensor(0.4825, grad_fn=<DivBackward0>)
# tensor(0.4941, grad_fn=<DivBackward0>)
# tensor(0.4969, grad_fn=<DivBackward0>)
# tensor(0.4763, grad_fn=<DivBackward0>)
# tensor(0.4758, grad_fn=<DivBackward0>)
# tensor(0.4908, grad_fn=<DivBackward0>)
# tensor(0.4804, grad_fn=<DivBackward0>)
# tensor(0.5054, grad_fn=<DivBackward0>)
# tensor(0.4808, grad_fn=<DivBackward0>)
# tensor(0.5151, grad_fn=<DivBackward0>)
# tensor(0.4840, grad_fn=<DivBackward0>)
# tensor(0.4316, grad_fn=<DivBackward0>)
# tensor(0.4885, grad_fn=<DivBackward0>)
# tensor(0.4993, grad_fn=<DivBackward0>)
# tensor(0.4633, grad_fn=<DivBackward0>)
# tensor(0.4656, grad_fn=<DivBackward0>)
# tensor(0.4768, grad_fn=<DivBackward0>)
# tensor(0.4957, grad_fn=<DivBackward0>)
# tensor(0.4636, grad_fn=<DivBackward0>)
# tensor(0.4872, grad_fn=<DivBackward0>)
# tensor(0.4738, grad_fn=<DivBackward0>)
# tensor(0.4704, grad_fn=<DivBackward0>)
# tensor(0.5010, grad_fn=<DivBackward0>)
# tensor(0.4546, grad_fn=<DivBackward0>)
# tensor(0.4652, grad_fn=<DivBackward0>)
# tensor(0.4343, grad_fn=<DivBackward0>)
# tensor(0.5478, grad_fn=<DivBackward0>)
# tensor(0.4919, grad_fn=<DivBackward0>)
# tensor(0.4881, grad_fn=<DivBackward0>)
# tensor(0.4685, grad_fn=<DivBackward0>)
# tensor(0.4799, grad_fn=<DivBackward0>)
# tensor(0.5104, grad_fn=<DivBackward0>)
# tensor(0.4867, grad_fn=<DivBackward0>)
# tensor(0.4914, grad_fn=<DivBackward0>)
# tensor(0.5089, grad_fn=<DivBackward0>)
# tensor(0.4910, grad_fn=<DivBackward0>)
# tensor(0.4739, grad_fn=<DivBackward0>)
# tensor(0.4747, grad_fn=<DivBackward0>)
# tensor(0.4788, grad_fn=<DivBackward0>)
# tensor(0.4585, grad_fn=<DivBackward0>)
# tensor(0.4806, grad_fn=<DivBackward0>)
# tensor(0.4735, grad_fn=<DivBackward0>)
# tensor(0.4665, grad_fn=<DivBackward0>)
# tensor(0.4858, grad_fn=<DivBackward0>)
# tensor(0.4699, grad_fn=<DivBackward0>)
# tensor(0.4510, grad_fn=<DivBackward0>)
# tensor(0.4605, grad_fn=<DivBackward0>)
# tensor(0.4670, grad_fn=<DivBackward0>)
# tensor(0.4698, grad_fn=<DivBackward0>)
# tensor(0.4916, grad_fn=<DivBackward0>)
# tensor(0.4623, grad_fn=<DivBackward0>)
# tensor(0.4807, grad_fn=<DivBackward0>)
# tensor(0.4919, grad_fn=<DivBackward0>)
# tensor(0.4725, grad_fn=<DivBackward0>)
# tensor(0.5102, grad_fn=<DivBackward0>)
# tensor(0.4955, grad_fn=<DivBackward0>)
# tensor(0.4839, grad_fn=<DivBackward0>)
# tensor(0.4614, grad_fn=<DivBackward0>)
# tensor(0.4782, grad_fn=<DivBackward0>)
# tensor(0.4595, grad_fn=<DivBackward0>)
# tensor(0.4370, grad_fn=<DivBackward0>)
# tensor(0.4702, grad_fn=<DivBackward0>)
# tensor(0.4443, grad_fn=<DivBackward0>)
# tensor(0.4963, grad_fn=<DivBackward0>)
# tensor(0.4991, grad_fn=<DivBackward0>)
# tensor(0.4907, grad_fn=<DivBackward0>)
# tensor(0.4574, grad_fn=<DivBackward0>)
# tensor(0.4987, grad_fn=<DivBackward0>)
# tensor(0.4754, grad_fn=<DivBackward0>)
# tensor(0.4883, grad_fn=<DivBackward0>)
# tensor(0.4738, grad_fn=<DivBackward0>)
# tensor(0.4904, grad_fn=<DivBackward0>)
# tensor(0.4769, grad_fn=<DivBackward0>)
# tensor(0.4621, grad_fn=<DivBackward0>)
# tensor(0.4771, grad_fn=<DivBackward0>)
# tensor(0.4740, grad_fn=<DivBackward0>)
# tensor(0.4845, grad_fn=<DivBackward0>)
# tensor(0.4453, grad_fn=<DivBackward0>)
# tensor(0.4539, grad_fn=<DivBackward0>)
# tensor(0.4417, grad_fn=<DivBackward0>)
# tensor(0.4946, grad_fn=<DivBackward0>)
# tensor(0.4499, grad_fn=<DivBackward0>)
# tensor(0.4663, grad_fn=<DivBackward0>)
# tensor(0.4589, grad_fn=<DivBackward0>)
# tensor(0.4876, grad_fn=<DivBackward0>)
# tensor(0.4578, grad_fn=<DivBackward0>)
# tensor(0.4285, grad_fn=<DivBackward0>)
# tensor(0.4387, grad_fn=<DivBackward0>)
# tensor(0.4527, grad_fn=<DivBackward0>)
# tensor(0.5122, grad_fn=<DivBackward0>)
# tensor(0.5355, grad_fn=<DivBackward0>)
# tensor(0.4340, grad_fn=<DivBackward0>)
# tensor(0.4579, grad_fn=<DivBackward0>)
# tensor(0.4889, grad_fn=<DivBackward0>)
# tensor(0.4604, grad_fn=<DivBackward0>)
# tensor(0.4928, grad_fn=<DivBackward0>)
# tensor(0.4683, grad_fn=<DivBackward0>)
# tensor(0.4471, grad_fn=<DivBackward0>)
# tensor(0.4863, grad_fn=<DivBackward0>)
# tensor(0.4730, grad_fn=<DivBackward0>)
# tensor(0.5059, grad_fn=<DivBackward0>)
# tensor(0.4725, grad_fn=<DivBackward0>)
# tensor(0.4553, grad_fn=<DivBackward0>)
# tensor(0.4578, grad_fn=<DivBackward0>)
# tensor(0.4487, grad_fn=<DivBackward0>)
# tensor(0.4613, grad_fn=<DivBackward0>)
# tensor(0.4966, grad_fn=<DivBackward0>)
# tensor(0.4833, grad_fn=<DivBackward0>)
# tensor(0.5087, grad_fn=<DivBackward0>)
# tensor(0.4750, grad_fn=<DivBackward0>)
# tensor(0.4501, grad_fn=<DivBackward0>)
# tensor(0.4422, grad_fn=<DivBackward0>)
# tensor(0.4697, grad_fn=<DivBackward0>)
# tensor(0.4305, grad_fn=<DivBackward0>)
# tensor(0.4955, grad_fn=<DivBackward0>)
# tensor(0.4826, grad_fn=<DivBackward0>)
# tensor(0.4502, grad_fn=<DivBackward0>)
# tensor(0.4943, grad_fn=<DivBackward0>)
# tensor(0.4988, grad_fn=<DivBackward0>)
# tensor(0.4568, grad_fn=<DivBackward0>)
# tensor(0.4296, grad_fn=<DivBackward0>)
# tensor(0.4633, grad_fn=<DivBackward0>)
# tensor(0.4565, grad_fn=<DivBackward0>)
# tensor(0.4462, grad_fn=<DivBackward0>)
# tensor(0.4623, grad_fn=<DivBackward0>)
# tensor(0.4445, grad_fn=<DivBackward0>)
# tensor(0.4918, grad_fn=<DivBackward0>)
# tensor(0.4740, grad_fn=<DivBackward0>)
# tensor(0.4442, grad_fn=<DivBackward0>)
# tensor(0.4794, grad_fn=<DivBackward0>)
# tensor(0.4871, grad_fn=<DivBackward0>)
# tensor(0.4446, grad_fn=<DivBackward0>)
# tensor(0.4858, grad_fn=<DivBackward0>)
# tensor(0.4686, grad_fn=<DivBackward0>)
# tensor(0.4568, grad_fn=<DivBackward0>)
# tensor(0.4597, grad_fn=<DivBackward0>)
# tensor(0.4627, grad_fn=<DivBackward0>)
# tensor(0.4558, grad_fn=<DivBackward0>)
# tensor(0.4711, grad_fn=<DivBackward0>)
# tensor(0.4639, grad_fn=<DivBackward0>)
# tensor(0.4821, grad_fn=<DivBackward0>)
# tensor(0.4709, grad_fn=<DivBackward0>)
# tensor(0.4787, grad_fn=<DivBackward0>)
# tensor(0.4636, grad_fn=<DivBackward0>)
# tensor(0.4530, grad_fn=<DivBackward0>)
# tensor(0.4251, grad_fn=<DivBackward0>)
# tensor(0.4777, grad_fn=<DivBackward0>)
# tensor(0.4514, grad_fn=<DivBackward0>)
# tensor(0.4601, grad_fn=<DivBackward0>)
# tensor(0.4554, grad_fn=<DivBackward0>)
# tensor(0.4599, grad_fn=<DivBackward0>)
# tensor(0.4882, grad_fn=<DivBackward0>)
# tensor(0.4566, grad_fn=<DivBackward0>)
# tensor(0.4989, grad_fn=<DivBackward0>)
# tensor(0.4886, grad_fn=<DivBackward0>)
# tensor(0.4587, grad_fn=<DivBackward0>)
# tensor(0.4846, grad_fn=<DivBackward0>)
# tensor(0.4673, grad_fn=<DivBackward0>)
# tensor(0.4470, grad_fn=<DivBackward0>)
# tensor(0.4309, grad_fn=<DivBackward0>)
# tensor(0.4340, grad_fn=<DivBackward0>)
# tensor(0.4819, grad_fn=<DivBackward0>)
# tensor(0.4657, grad_fn=<DivBackward0>)
# tensor(0.4821, grad_fn=<DivBackward0>)
# tensor(0.5030, grad_fn=<DivBackward0>)
# tensor(0.4777, grad_fn=<DivBackward0>)
# tensor(0.4787, grad_fn=<DivBackward0>)
# tensor(0.4647, grad_fn=<DivBackward0>)
# tensor(0.4464, grad_fn=<DivBackward0>)
# tensor(0.4592, grad_fn=<DivBackward0>)
# tensor(0.4588, grad_fn=<DivBackward0>)
# tensor(0.4397, grad_fn=<DivBackward0>)
# tensor(0.4815, grad_fn=<DivBackward0>)
# tensor(0.4233, grad_fn=<DivBackward0>)
# tensor(0.4712, grad_fn=<DivBackward0>)
# tensor(0.4641, grad_fn=<DivBackward0>)
# tensor(0.4480, grad_fn=<DivBackward0>)
# tensor(0.4331, grad_fn=<DivBackward0>)
# tensor(0.4572, grad_fn=<DivBackward0>)
# tensor(0.4650, grad_fn=<DivBackward0>)
# tensor(0.4685, grad_fn=<DivBackward0>)
# tensor(0.4691, grad_fn=<DivBackward0>)
# tensor(0.4343, grad_fn=<DivBackward0>)
# tensor(0.4755, grad_fn=<DivBackward0>)
# tensor(0.4185, grad_fn=<DivBackward0>)
# tensor(0.4610, grad_fn=<DivBackward0>)
# tensor(0.4537, grad_fn=<DivBackward0>)
# tensor(0.4700, grad_fn=<DivBackward0>)
# tensor(0.4596, grad_fn=<DivBackward0>)
# tensor(0.4291, grad_fn=<DivBackward0>)
# tensor(0.4443, grad_fn=<DivBackward0>)
# tensor(0.4715, grad_fn=<DivBackward0>)
# tensor(0.4438, grad_fn=<DivBackward0>)
# tensor(0.4538, grad_fn=<DivBackward0>)
# tensor(0.4845, grad_fn=<DivBackward0>)
# tensor(0.4906, grad_fn=<DivBackward0>)
# tensor(0.4360, grad_fn=<DivBackward0>)
# tensor(0.5000, grad_fn=<DivBackward0>)
# tensor(0.4544, grad_fn=<DivBackward0>)
# tensor(0.4648, grad_fn=<DivBackward0>)
# tensor(0.4828, grad_fn=<DivBackward0>)
# tensor(0.4446, grad_fn=<DivBackward0>)
# tensor(0.4775, grad_fn=<DivBackward0>)
# tensor(0.4764, grad_fn=<DivBackward0>)
# tensor(0.4643, grad_fn=<DivBackward0>)
# tensor(0.4770, grad_fn=<DivBackward0>)
# tensor(0.4688, grad_fn=<DivBackward0>)
# tensor(0.4375, grad_fn=<DivBackward0>)
# tensor(0.4473, grad_fn=<DivBackward0>)
# tensor(0.4540, grad_fn=<DivBackward0>)
# tensor(0.4894, grad_fn=<DivBackward0>)
# tensor(0.4584, grad_fn=<DivBackward0>)
# tensor(0.4863, grad_fn=<DivBackward0>)
# tensor(0.4756, grad_fn=<DivBackward0>)
# tensor(0.4542, grad_fn=<DivBackward0>)
# tensor(0.4528, grad_fn=<DivBackward0>)
# tensor(0.4746, grad_fn=<DivBackward0>)
# tensor(0.4356, grad_fn=<DivBackward0>)
# tensor(0.4386, grad_fn=<DivBackward0>)
# tensor(0.4865, grad_fn=<DivBackward0>)
# tensor(0.4299, grad_fn=<DivBackward0>)
# tensor(0.4274, grad_fn=<DivBackward0>)
# tensor(0.4651, grad_fn=<DivBackward0>)
# tensor(0.4815, grad_fn=<DivBackward0>)
# tensor(0.4784, grad_fn=<DivBackward0>)
# tensor(0.4296, grad_fn=<DivBackward0>)
# tensor(0.4173, grad_fn=<DivBackward0>)
# tensor(0.4493, grad_fn=<DivBackward0>)
# tensor(0.4654, grad_fn=<DivBackward0>)
# tensor(0.4735, grad_fn=<DivBackward0>)
# tensor(0.4839, grad_fn=<DivBackward0>)
# tensor(0.4755, grad_fn=<DivBackward0>)
# tensor(0.4665, grad_fn=<DivBackward0>)
# tensor(0.3978, grad_fn=<DivBackward0>)
# tensor(0.4307, grad_fn=<DivBackward0>)
# tensor(0.4022, grad_fn=<DivBackward0>)
# tensor(0.4543, grad_fn=<DivBackward0>)
# tensor(0.4408, grad_fn=<DivBackward0>)
# tensor(0.4777, grad_fn=<DivBackward0>)
# tensor(0.4522, grad_fn=<DivBackward0>)
# tensor(0.4575, grad_fn=<DivBackward0>)
# tensor(0.4481, grad_fn=<DivBackward0>)
# tensor(0.4217, grad_fn=<DivBackward0>)
# tensor(0.4395, grad_fn=<DivBackward0>)
# tensor(0.4168, grad_fn=<DivBackward0>)
# tensor(0.4375, grad_fn=<DivBackward0>)
# tensor(0.4555, grad_fn=<DivBackward0>)
# tensor(0.4633, grad_fn=<DivBackward0>)
# tensor(0.4861, grad_fn=<DivBackward0>)
# tensor(0.4515, grad_fn=<DivBackward0>)
# tensor(0.4541, grad_fn=<DivBackward0>)
# tensor(0.4414, grad_fn=<DivBackward0>)
# tensor(0.4476, grad_fn=<DivBackward0>)
# tensor(0.4795, grad_fn=<DivBackward0>)
# tensor(0.4115, grad_fn=<DivBackward0>)
# tensor(0.4633, grad_fn=<DivBackward0>)
# tensor(0.4435, grad_fn=<DivBackward0>)
# tensor(0.4523, grad_fn=<DivBackward0>)
# tensor(0.4484, grad_fn=<DivBackward0>)
# tensor(0.4318, grad_fn=<DivBackward0>)
# tensor(0.4811, grad_fn=<DivBackward0>)
# tensor(0.4388, grad_fn=<DivBackward0>)
# tensor(0.4401, grad_fn=<DivBackward0>)
# tensor(0.4486, grad_fn=<DivBackward0>)
# tensor(0.4646, grad_fn=<DivBackward0>)
# tensor(0.4656, grad_fn=<DivBackward0>)
# tensor(0.4299, grad_fn=<DivBackward0>)
# tensor(0.4566, grad_fn=<DivBackward0>)
# tensor(0.4485, grad_fn=<DivBackward0>)
# tensor(0.3997, grad_fn=<DivBackward0>)
# tensor(0.4423, grad_fn=<DivBackward0>)
# tensor(0.4462, grad_fn=<DivBackward0>)
# tensor(0.4295, grad_fn=<DivBackward0>)
# tensor(0.4583, grad_fn=<DivBackward0>)
# tensor(0.4588, grad_fn=<DivBackward0>)
# tensor(0.4430, grad_fn=<DivBackward0>)
# tensor(0.4378, grad_fn=<DivBackward0>)
# tensor(0.4256, grad_fn=<DivBackward0>)
# tensor(0.4046, grad_fn=<DivBackward0>)
# tensor(0.4543, grad_fn=<DivBackward0>)
# tensor(0.4684, grad_fn=<DivBackward0>)
# tensor(0.4312, grad_fn=<DivBackward0>)
# tensor(0.4309, grad_fn=<DivBackward0>)
# tensor(0.4460, grad_fn=<DivBackward0>)
# tensor(0.4180, grad_fn=<DivBackward0>)
# tensor(0.3995, grad_fn=<DivBackward0>)
# tensor(0.4486, grad_fn=<DivBackward0>)
# tensor(0.4441, grad_fn=<DivBackward0>)
# tensor(0.4707, grad_fn=<DivBackward0>)
# tensor(0.4730, grad_fn=<DivBackward0>)
# tensor(0.4289, grad_fn=<DivBackward0>)
# tensor(0.4209, grad_fn=<DivBackward0>)
# tensor(0.4293, grad_fn=<DivBackward0>)
# tensor(0.4186, grad_fn=<DivBackward0>)
# tensor(0.4401, grad_fn=<DivBackward0>)
# tensor(0.4282, grad_fn=<DivBackward0>)
# tensor(0.4819, grad_fn=<DivBackward0>)
# tensor(0.4494, grad_fn=<DivBackward0>)
# tensor(0.4537, grad_fn=<DivBackward0>)
# tensor(0.4140, grad_fn=<DivBackward0>)
# tensor(0.3879, grad_fn=<DivBackward0>)
# tensor(0.4693, grad_fn=<DivBackward0>)
# tensor(0.4400, grad_fn=<DivBackward0>)
# tensor(0.4065, grad_fn=<DivBackward0>)
# tensor(0.4786, grad_fn=<DivBackward0>)
# tensor(0.4845, grad_fn=<DivBackward0>)
# tensor(0.4663, grad_fn=<DivBackward0>)
# tensor(0.4529, grad_fn=<DivBackward0>)
# tensor(0.4271, grad_fn=<DivBackward0>)
# tensor(0.4515, grad_fn=<DivBackward0>)
# tensor(0.4218, grad_fn=<DivBackward0>)
# tensor(0.4436, grad_fn=<DivBackward0>)
# tensor(0.4269, grad_fn=<DivBackward0>)
# tensor(0.4505, grad_fn=<DivBackward0>)
# tensor(0.4357, grad_fn=<DivBackward0>)
# tensor(0.4378, grad_fn=<DivBackward0>)
# tensor(0.4530, grad_fn=<DivBackward0>)
# tensor(0.4400, grad_fn=<DivBackward0>)
# tensor(0.4727, grad_fn=<DivBackward0>)
# tensor(0.4488, grad_fn=<DivBackward0>)
# tensor(0.4741, grad_fn=<DivBackward0>)
# tensor(0.4652, grad_fn=<DivBackward0>)
# tensor(0.4622, grad_fn=<DivBackward0>)
# tensor(0.4170, grad_fn=<DivBackward0>)
# tensor(0.4188, grad_fn=<DivBackward0>)
# tensor(0.4567, grad_fn=<DivBackward0>)
# tensor(0.4733, grad_fn=<DivBackward0>)
# tensor(0.4514, grad_fn=<DivBackward0>)
# tensor(0.4428, grad_fn=<DivBackward0>)
# tensor(0.4679, grad_fn=<DivBackward0>)
# tensor(0.3834, grad_fn=<DivBackward0>)
# tensor(0.4472, grad_fn=<DivBackward0>)
# tensor(0.4094, grad_fn=<DivBackward0>)
# tensor(0.4000, grad_fn=<DivBackward0>)
# tensor(0.4101, grad_fn=<DivBackward0>)
# tensor(0.4536, grad_fn=<DivBackward0>)
# tensor(0.4743, grad_fn=<DivBackward0>)
# tensor(0.4515, grad_fn=<DivBackward0>)
# tensor(0.4605, grad_fn=<DivBackward0>)
# tensor(0.4425, grad_fn=<DivBackward0>)
# tensor(0.4832, grad_fn=<DivBackward0>)
# tensor(0.4624, grad_fn=<DivBackward0>)
# tensor(0.4561, grad_fn=<DivBackward0>)
# tensor(0.4531, grad_fn=<DivBackward0>)
# tensor(0.4526, grad_fn=<DivBackward0>)
# tensor(0.4493, grad_fn=<DivBackward0>)
# tensor(0.4279, grad_fn=<DivBackward0>)
# tensor(0.4159, grad_fn=<DivBackward0>)
# tensor(0.4610, grad_fn=<DivBackward0>)
# tensor(0.4161, grad_fn=<DivBackward0>)
# tensor(0.4256, grad_fn=<DivBackward0>)
# tensor(0.4382, grad_fn=<DivBackward0>)
# tensor(0.4368, grad_fn=<DivBackward0>)
# tensor(0.4413, grad_fn=<DivBackward0>)
# tensor(0.4463, grad_fn=<DivBackward0>)
# tensor(0.3999, grad_fn=<DivBackward0>)
# tensor(0.4554, grad_fn=<DivBackward0>)
# tensor(0.4282, grad_fn=<DivBackward0>)
# tensor(0.4436, grad_fn=<DivBackward0>)
# tensor(0.4427, grad_fn=<DivBackward0>)
# tensor(0.4584, grad_fn=<DivBackward0>)
# tensor(0.4618, grad_fn=<DivBackward0>)
# tensor(0.4205, grad_fn=<DivBackward0>)
# tensor(0.4609, grad_fn=<DivBackward0>)
# tensor(0.4425, grad_fn=<DivBackward0>)
# tensor(0.4481, grad_fn=<DivBackward0>)
# tensor(0.4348, grad_fn=<DivBackward0>)
# tensor(0.4504, grad_fn=<DivBackward0>)
# tensor(0.4460, grad_fn=<DivBackward0>)
# tensor(0.4433, grad_fn=<DivBackward0>)
# tensor(0.4171, grad_fn=<DivBackward0>)
# tensor(0.4253, grad_fn=<DivBackward0>)
# tensor(0.4146, grad_fn=<DivBackward0>)
# tensor(0.4744, grad_fn=<DivBackward0>)
# tensor(0.4422, grad_fn=<DivBackward0>)
# tensor(0.4366, grad_fn=<DivBackward0>)
# tensor(0.4377, grad_fn=<DivBackward0>)
# tensor(0.4327, grad_fn=<DivBackward0>)
# tensor(0.4453, grad_fn=<DivBackward0>)
# tensor(0.4315, grad_fn=<DivBackward0>)
# tensor(0.4197, grad_fn=<DivBackward0>)
# tensor(0.4666, grad_fn=<DivBackward0>)
# tensor(0.4537, grad_fn=<DivBackward0>)
# tensor(0.4635, grad_fn=<DivBackward0>)
# tensor(0.4496, grad_fn=<DivBackward0>)
# tensor(0.4706, grad_fn=<DivBackward0>)
# tensor(0.4441, grad_fn=<DivBackward0>)
# tensor(0.4511, grad_fn=<DivBackward0>)
# tensor(0.4522, grad_fn=<DivBackward0>)
# tensor(0.4426, grad_fn=<DivBackward0>)
# tensor(0.4623, grad_fn=<DivBackward0>)
# tensor(0.4512, grad_fn=<DivBackward0>)
# tensor(0.4094, grad_fn=<DivBackward0>)
# tensor(0.4297, grad_fn=<DivBackward0>)
# tensor(0.4404, grad_fn=<DivBackward0>)
# tensor(0.4461, grad_fn=<DivBackward0>)
# tensor(0.4616, grad_fn=<DivBackward0>)
# tensor(0.4413, grad_fn=<DivBackward0>)
# tensor(0.4595, grad_fn=<DivBackward0>)
# tensor(0.4379, grad_fn=<DivBackward0>)
# tensor(0.4444, grad_fn=<DivBackward0>)
# tensor(0.4342, grad_fn=<DivBackward0>)
# tensor(0.4397, grad_fn=<DivBackward0>)
# tensor(0.4073, grad_fn=<DivBackward0>)
# tensor(0.4378, grad_fn=<DivBackward0>)
# tensor(0.4021, grad_fn=<DivBackward0>)
# tensor(0.4243, grad_fn=<DivBackward0>)
# tensor(0.5048, grad_fn=<DivBackward0>)
# tensor(0.4131, grad_fn=<DivBackward0>)
# tensor(0.4206, grad_fn=<DivBackward0>)
# tensor(0.4216, grad_fn=<DivBackward0>)
# tensor(0.4563, grad_fn=<DivBackward0>)
# tensor(0.4171, grad_fn=<DivBackward0>)
# tensor(0.4282, grad_fn=<DivBackward0>)
# tensor(0.4138, grad_fn=<DivBackward0>)
# tensor(0.4303, grad_fn=<DivBackward0>)
# tensor(0.4773, grad_fn=<DivBackward0>)
# tensor(0.4407, grad_fn=<DivBackward0>)
# tensor(0.4562, grad_fn=<DivBackward0>)
# tensor(0.4539, grad_fn=<DivBackward0>)
# tensor(0.4192, grad_fn=<DivBackward0>)
# tensor(0.4032, grad_fn=<DivBackward0>)
# tensor(0.4500, grad_fn=<DivBackward0>)
# tensor(0.4475, grad_fn=<DivBackward0>)
# tensor(0.4537, grad_fn=<DivBackward0>)
# tensor(0.4240, grad_fn=<DivBackward0>)
# tensor(0.4174, grad_fn=<DivBackward0>)
# tensor(0.4182, grad_fn=<DivBackward0>)
# tensor(0.3842, grad_fn=<DivBackward0>)
# tensor(0.4014, grad_fn=<DivBackward0>)
# tensor(0.4285, grad_fn=<DivBackward0>)
# tensor(0.4344, grad_fn=<DivBackward0>)
# tensor(0.4302, grad_fn=<DivBackward0>)
# tensor(0.4652, grad_fn=<DivBackward0>)
# tensor(0.4421, grad_fn=<DivBackward0>)
# tensor(0.3908, grad_fn=<DivBackward0>)
# tensor(0.4185, grad_fn=<DivBackward0>)
# tensor(0.4389, grad_fn=<DivBackward0>)
# tensor(0.4541, grad_fn=<DivBackward0>)
# tensor(0.4260, grad_fn=<DivBackward0>)
# tensor(0.4155, grad_fn=<DivBackward0>)
# tensor(0.4182, grad_fn=<DivBackward0>)
# tensor(0.4465, grad_fn=<DivBackward0>)
# tensor(0.4401, grad_fn=<DivBackward0>)
# tensor(0.4302, grad_fn=<DivBackward0>)
# tensor(0.4050, grad_fn=<DivBackward0>)
# tensor(0.4328, grad_fn=<DivBackward0>)
# tensor(0.3972, grad_fn=<DivBackward0>)
# tensor(0.4214, grad_fn=<DivBackward0>)
# tensor(0.4462, grad_fn=<DivBackward0>)
# tensor(0.4219, grad_fn=<DivBackward0>)
# tensor(0.4732, grad_fn=<DivBackward0>)
# tensor(0.4085, grad_fn=<DivBackward0>)
# tensor(0.4364, grad_fn=<DivBackward0>)
# tensor(0.4095, grad_fn=<DivBackward0>)
# tensor(0.4424, grad_fn=<DivBackward0>)
# tensor(0.4396, grad_fn=<DivBackward0>)
# tensor(0.4544, grad_fn=<DivBackward0>)
# tensor(0.4080, grad_fn=<DivBackward0>)
# tensor(0.4533, grad_fn=<DivBackward0>)
# tensor(0.4138, grad_fn=<DivBackward0>)
# tensor(0.4727, grad_fn=<DivBackward0>)
# tensor(0.4505, grad_fn=<DivBackward0>)
# tensor(0.4371, grad_fn=<DivBackward0>)
# tensor(0.4584, grad_fn=<DivBackward0>)
# tensor(0.4464, grad_fn=<DivBackward0>)
# tensor(0.4137, grad_fn=<DivBackward0>)
# tensor(0.4421, grad_fn=<DivBackward0>)
# tensor(0.4353, grad_fn=<DivBackward0>)
# tensor(0.4344, grad_fn=<DivBackward0>)
# tensor(0.4267, grad_fn=<DivBackward0>)
# tensor(0.4568, grad_fn=<DivBackward0>)
# tensor(0.4250, grad_fn=<DivBackward0>)
# tensor(0.3933, grad_fn=<DivBackward0>)
# tensor(0.4393, grad_fn=<DivBackward0>)
# tensor(0.4492, grad_fn=<DivBackward0>)
# tensor(0.4450, grad_fn=<DivBackward0>)
# tensor(0.4270, grad_fn=<DivBackward0>)
# tensor(0.4468, grad_fn=<DivBackward0>)
# tensor(0.4175, grad_fn=<DivBackward0>)
# tensor(0.4127, grad_fn=<DivBackward0>)
# tensor(0.4356, grad_fn=<DivBackward0>)
# tensor(0.4097, grad_fn=<DivBackward0>)
# tensor(0.4099, grad_fn=<DivBackward0>)
# tensor(0.4710, grad_fn=<DivBackward0>)
# tensor(0.4455, grad_fn=<DivBackward0>)
# tensor(0.4182, grad_fn=<DivBackward0>)
# tensor(0.4154, grad_fn=<DivBackward0>)
# tensor(0.4127, grad_fn=<DivBackward0>)
# tensor(0.4169, grad_fn=<DivBackward0>)
# tensor(0.4185, grad_fn=<DivBackward0>)
# tensor(0.3995, grad_fn=<DivBackward0>)
# tensor(0.4423, grad_fn=<DivBackward0>)
# tensor(0.4170, grad_fn=<DivBackward0>)
# tensor(0.4825, grad_fn=<DivBackward0>)
# tensor(0.4588)
# tensor(0.4253)
# tensor(0.4623)
# tensor(0.4238)
# tensor(0.4614)
# tensor(0.4564)
# tensor(0.4409)
# tensor(0.4257)
# tensor(0.4217)
# tensor(0.4322)
# tensor(0.4467)
# tensor(0.4303)
# tensor(0.4264)
# tensor(0.4058)
# tensor(0.4084)
# tensor(0.4356)
# tensor(0.4204)
# tensor(0.4441)
# tensor(0.4117)
# tensor(0.4561)
# tensor(0.4548)
# tensor(0.4485)
# tensor(0.4603)
# tensor(0.4682)
# tensor(0.4089)
# tensor(0.4411)
# tensor(0.4242)
# tensor(0.4399)
# tensor(0.3886)
# tensor(0.4328)
#
# train set: Average loss: 0.0066, Accuracy: 1555/1984 (78%)
#
# tensor(0.4249)
# tensor(0.4503)
# tensor(0.4039)
# tensor(0.4178)
# tensor(0.4279)
# tensor(0.3840)
# tensor(0.4246)
# tensor(0.3960)
# tensor(0.4007)
# tensor(0.4248)
# tensor(0.4215)
# tensor(0.4488)
# tensor(0.4416)
# tensor(0.4465)
# tensor(0.4495)
# tensor(0.4316)
# tensor(0.4195)
# tensor(0.4022)
# tensor(0.4200)
# tensor(0.4146)
# tensor(0.4532)
# tensor(0.4735)
# tensor(0.4054)
# tensor(0.4486)
# tensor(0.4282)
# tensor(0.4464)
# tensor(0.4376)
# tensor(0.4221)
# tensor(0.4503)
# tensor(0.3943)
#
# test set: Average loss: 0.0065, Accuracy: 1604/1984 (81%)
#
# tensor(0.4784, grad_fn=<DivBackward0>)
# tensor(0.4309, grad_fn=<DivBackward0>)
# tensor(0.3970, grad_fn=<DivBackward0>)
# tensor(0.4170, grad_fn=<DivBackward0>)
# tensor(0.4324, grad_fn=<DivBackward0>)
# tensor(0.4216, grad_fn=<DivBackward0>)
# tensor(0.4156, grad_fn=<DivBackward0>)
# tensor(0.4266, grad_fn=<DivBackward0>)
# tensor(0.4038, grad_fn=<DivBackward0>)
# tensor(0.4434, grad_fn=<DivBackward0>)
# tensor(0.4240, grad_fn=<DivBackward0>)
# tensor(0.4578, grad_fn=<DivBackward0>)
# tensor(0.4491, grad_fn=<DivBackward0>)
# tensor(0.4260, grad_fn=<DivBackward0>)
# tensor(0.4320, grad_fn=<DivBackward0>)
# tensor(0.3972, grad_fn=<DivBackward0>)
# tensor(0.4209, grad_fn=<DivBackward0>)
# tensor(0.4518, grad_fn=<DivBackward0>)
# tensor(0.4166, grad_fn=<DivBackward0>)
# tensor(0.3930, grad_fn=<DivBackward0>)
# tensor(0.4541, grad_fn=<DivBackward0>)
# tensor(0.4804, grad_fn=<DivBackward0>)
# tensor(0.4039, grad_fn=<DivBackward0>)
# tensor(0.3947, grad_fn=<DivBackward0>)
# tensor(0.4780, grad_fn=<DivBackward0>)
# tensor(0.4246, grad_fn=<DivBackward0>)
# tensor(0.4673, grad_fn=<DivBackward0>)
# tensor(0.4614, grad_fn=<DivBackward0>)
# tensor(0.4216, grad_fn=<DivBackward0>)
# tensor(0.4065, grad_fn=<DivBackward0>)
# tensor(0.4161, grad_fn=<DivBackward0>)
# tensor(0.4342, grad_fn=<DivBackward0>)
# tensor(0.4551, grad_fn=<DivBackward0>)
# tensor(0.4372, grad_fn=<DivBackward0>)
# tensor(0.4394, grad_fn=<DivBackward0>)
# tensor(0.4565, grad_fn=<DivBackward0>)
# tensor(0.4519, grad_fn=<DivBackward0>)
# tensor(0.4632, grad_fn=<DivBackward0>)
# tensor(0.4405, grad_fn=<DivBackward0>)
# tensor(0.4226, grad_fn=<DivBackward0>)
# tensor(0.4469, grad_fn=<DivBackward0>)
# tensor(0.4489, grad_fn=<DivBackward0>)
# tensor(0.4582, grad_fn=<DivBackward0>)
# tensor(0.4232, grad_fn=<DivBackward0>)
# tensor(0.3945, grad_fn=<DivBackward0>)
# tensor(0.3911, grad_fn=<DivBackward0>)
# tensor(0.4554, grad_fn=<DivBackward0>)
# tensor(0.4163, grad_fn=<DivBackward0>)
# tensor(0.3799, grad_fn=<DivBackward0>)
# tensor(0.4183, grad_fn=<DivBackward0>)
# tensor(0.4203, grad_fn=<DivBackward0>)
# tensor(0.3929, grad_fn=<DivBackward0>)
# tensor(0.4181, grad_fn=<DivBackward0>)
# tensor(0.3933, grad_fn=<DivBackward0>)
# tensor(0.4238, grad_fn=<DivBackward0>)
# tensor(0.4116, grad_fn=<DivBackward0>)
# tensor(0.4092, grad_fn=<DivBackward0>)
# tensor(0.4183, grad_fn=<DivBackward0>)
# tensor(0.4226, grad_fn=<DivBackward0>)
# tensor(0.4233, grad_fn=<DivBackward0>)
# tensor(0.4379, grad_fn=<DivBackward0>)
# tensor(0.4133, grad_fn=<DivBackward0>)
# tensor(0.4662, grad_fn=<DivBackward0>)
# tensor(0.4192, grad_fn=<DivBackward0>)
# tensor(0.4351, grad_fn=<DivBackward0>)
# tensor(0.4506, grad_fn=<DivBackward0>)
# tensor(0.3896, grad_fn=<DivBackward0>)
# tensor(0.4154, grad_fn=<DivBackward0>)
# tensor(0.4035, grad_fn=<DivBackward0>)
# tensor(0.4506, grad_fn=<DivBackward0>)
# tensor(0.4341, grad_fn=<DivBackward0>)
# tensor(0.4214, grad_fn=<DivBackward0>)
# tensor(0.4506, grad_fn=<DivBackward0>)
# tensor(0.3740, grad_fn=<DivBackward0>)
# tensor(0.4300, grad_fn=<DivBackward0>)
# tensor(0.4253, grad_fn=<DivBackward0>)
# tensor(0.4289, grad_fn=<DivBackward0>)
# tensor(0.4604, grad_fn=<DivBackward0>)
# tensor(0.4296, grad_fn=<DivBackward0>)
# tensor(0.4235, grad_fn=<DivBackward0>)
# tensor(0.4387, grad_fn=<DivBackward0>)
# tensor(0.4272, grad_fn=<DivBackward0>)
# tensor(0.4274, grad_fn=<DivBackward0>)
# tensor(0.4193, grad_fn=<DivBackward0>)
# tensor(0.4048, grad_fn=<DivBackward0>)
# tensor(0.4363, grad_fn=<DivBackward0>)
# tensor(0.4314, grad_fn=<DivBackward0>)
# tensor(0.4201, grad_fn=<DivBackward0>)
# tensor(0.4197, grad_fn=<DivBackward0>)
# tensor(0.4502, grad_fn=<DivBackward0>)
# tensor(0.4602, grad_fn=<DivBackward0>)
# tensor(0.4369, grad_fn=<DivBackward0>)
# tensor(0.4205, grad_fn=<DivBackward0>)
# tensor(0.4269, grad_fn=<DivBackward0>)
# tensor(0.3922, grad_fn=<DivBackward0>)
# tensor(0.4164, grad_fn=<DivBackward0>)
# tensor(0.3984, grad_fn=<DivBackward0>)
# tensor(0.4292, grad_fn=<DivBackward0>)
# tensor(0.4266, grad_fn=<DivBackward0>)
# tensor(0.4040, grad_fn=<DivBackward0>)
# tensor(0.4009, grad_fn=<DivBackward0>)
# tensor(0.4125, grad_fn=<DivBackward0>)
# tensor(0.4076, grad_fn=<DivBackward0>)
# tensor(0.4447, grad_fn=<DivBackward0>)
# tensor(0.4495, grad_fn=<DivBackward0>)
# tensor(0.4004, grad_fn=<DivBackward0>)
# tensor(0.4574, grad_fn=<DivBackward0>)
# tensor(0.4380, grad_fn=<DivBackward0>)

# %%
fig=plt.figure(figsize=(10,5))

plt.subplot(121)
plt.plot(train_stats[:,0],'-k',label='train loss')
plt.plot(test_stats[:,0],'-r',label='test loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()

plt.subplot(122)
plt.plot(train_stats[:,1],'-k',label='train acc')
plt.plot(test_stats[:,1],'-r',label='test acc')
plt.xlabel('epoch')
plt.ylabel('acc')
plt.legend()


plt.show()
